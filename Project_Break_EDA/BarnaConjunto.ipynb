# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_BarcelonaSept24 = pd.read_csv(r'C:\Users\alber\Downloads\listingsB06Sep24.csv')
df_BarcelonaJune24 =pd.read_csv(r'C:\Users\alber\Downloads\listingsB15June24.csv')
df_BarcelonaMarch24 = pd.read_csv(r'C:\Users\alber\Downloads\listingsB20March24.csv')
df_BarcelonaDec23 = pd.read_csv(r'C:\Users\alber\Downloads\listingsB13Dec23.csv')

# %%
df_BarcelonaSept24['month'] = 'September'
df_BarcelonaMarch24['month'] = 'March'
df_BarcelonaJune24['month'] = 'June'
df_BarcelonaDec23['month'] = 'December' 

df_concatenado_Barcelona = pd.concat([df_BarcelonaSept24, df_BarcelonaMarch24, df_BarcelonaJune24, df_BarcelonaDec23], ignore_index=True)

# %%
df_concatenado_Barcelona_copia = df_concatenado_Barcelona.copy()

# %%
df_concatenado_Barcelona_copia = df_concatenado_Barcelona_copia.dropna()

# %%
# Calcular precios promedio por mes
monthly_prices = df_concatenado_Barcelona_copia.groupby('month')['price'].mean()

# Visualización de precios promedio por mes
plt.figure(figsize=(12, 6))

# Usar un 'hue' para asociar el color, aunque no es necesario en este caso
sns.barplot(x=monthly_prices.index, y=monthly_prices.values, hue=monthly_prices.index, palette="viridis", legend=False)

# Títulos y etiquetas
plt.title("Precios promedio por mes (Estacionalidad)", fontsize=16)
plt.xlabel("Mes", fontsize=12)
plt.ylabel("Precio promedio (€)", fontsize=12)
plt.xticks(rotation=45)

# Ajuste del diseño
plt.tight_layout()
plt.show()

# %%
df_concatenado_Barcelona_copia.head(80000)
# Out:
#                         id                                               name  \
# 0                    18674    Huge flat for 8 people close to Sagrada Familia
# 1                    23197  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                    32711                   Sagrada Familia area - Còrsega 1
# 3                    34241   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4                    34981               VIDRE HOME PLAZA REAL on LAS RAMBLAS
# ...                    ...                                                ...
# 75098  1029582058185779855  Rental unit in Barcelona · ★New · Studio · 1 b...
# 75109  1035275935626477703  Rental unit in Barcelona · ★New · 3 bedrooms ·...
# 75141  1036935367643427485  Rental unit in Barcelona · ★New · 3 bedrooms ·...
# 75143  1037001392007124702  Rental unit in Barcelona · ★New · 1 bedroom · ...
# 75144  1037195344290857786  Rental unit in Barcelona · ★New · 3 bedrooms ·...
#
# ...

# %%
# 1. Vista general del dataset
print(df_concatenado_Barcelona_copia.info())
print(df_concatenado_Barcelona_copia.describe())
print(df_concatenado_Barcelona_copia.head())

# 2. Verificar valores nulos
print(df_concatenado_Barcelona_copia.isnull().sum())

# 3. Limpiar y convertir la columna 'price' a numérica (puede tener símbolos no numéricos)
# Eliminar símbolos como "$" y comas en la columna 'price'
df_concatenado_Barcelona_copia['price'] = df_concatenado_Barcelona_copia['price'].replace({'\\$': '', ',': ''}, regex=True)

# Convertir la columna 'price' a tipo numérico, con 'coerce' para manejar los errores y convertir a NaN cuando no se pueda
df_concatenado_Barcelona_copia['price'] = pd.to_numeric(df_concatenado_Barcelona_copia['price'], errors='coerce')

# Verifica que la conversión sea exitosa
print(df_concatenado_Barcelona_copia['price'].describe())

# 4. Filtrar solo las columnas numéricas para análisis
df_numerico = df_concatenado_Barcelona_copia.select_dtypes(include=[np.number])

# Verificar que las columnas numéricas son las correctas
print(df_numerico.columns)

# 5. Estadísticas generales para la columna 'price'
print(df_numerico['price'].describe())  # Estadísticas para precios, por ejemplo

# 6. Distribución de precios
plt.figure(figsize=(10, 6))
sns.histplot(df_numerico['price'], bins=50, kde=True)
plt.title('Distribución de Precios')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# 7. Análisis de precios por barrio
# Verificar si 'neighbourhood_group' es una columna numérica o categórica
plt.figure(figsize=(12, 6))
sns.boxplot(x='neighbourhood_group', y='price', data=df_concatenado_Barcelona_copia)
plt.title('Precios por Barrio')
plt.xlabel('Barrio')
plt.ylabel('Precio')
plt.show()

# 8. Relación entre características y el precio
# Asegúrate de que 'longitude' y 'latitude' son numéricas antes de hacer el gráfico
df_concatenado_Barcelona_copia['longitude'] = pd.to_numeric(df_concatenado_Barcelona_copia['longitude'], errors='coerce')
df_concatenado_Barcelona_copia['latitude'] = pd.to_numeric(df_concatenado_Barcelona_copia['latitude'], errors='coerce')

# Solo usar columnas numéricas
plt.figure(figsize=(10, 6))
sns.scatterplot(x='longitude', y='latitude', hue='price', data=df_concatenado_Barcelona_copia, palette='viridis')
plt.title('Precio en relación con la ubicación')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.show()

# 9. Correlación entre variables numéricas
correlation_matrix = df_numerico.corr()  # Utilizar solo columnas numéricas
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlación')
plt.show()

# 10. Análisis de la disponibilidad
sns.countplot(x='availability_365', data=df_concatenado_Barcelona_copia)
plt.title('Disponibilidad en el Año')
plt.xlabel('Disponibilidad (días)')
plt.ylabel('Frecuencia')
plt.show()

# Distribución de las propiedades por tipo de habitación
plt.figure(figsize=(10, 6))
sns.countplot(x='room_type', data=df_concatenado_Barcelona_copia)
plt.title('Distribución de Propiedades por Tipo de Habitación')
plt.xlabel('Tipo de Habitación')
plt.ylabel('Frecuencia')
plt.show()

# Relación entre el número de huéspedes y el precio
plt.figure(figsize=(10, 6))
sns.scatterplot(x='room_type', y='price', data=df_concatenado_Barcelona_copia)
plt.title('Relación entre el número de huéspedes y el precio')
plt.xlabel('Número de Huéspedes')
plt.ylabel('Precio')
plt.show()

# Si tienes una columna de fecha, como 'last_review', puedes extraer el día de la semana y analizarlo
df_concatenado_Barcelona_copia['last_review'] = pd.to_datetime(df_concatenado_Barcelona_copia['last_review'], errors='coerce')
df_concatenado_Barcelona_copia['day_of_week'] = df_concatenado_Barcelona_copia['last_review'].dt.day_name()

# Análisis de precios por día de la semana
plt.figure(figsize=(10, 6))
sns.boxplot(x='day_of_week', y='price', data=df_concatenado_Barcelona_copia)
plt.title('Precios por Día de la Semana')
plt.xlabel('Día de la Semana')
plt.ylabel('Precio')
plt.show()

# Propiedades con mayor y menor disponibilidad
top_available = df_concatenado_Barcelona_copia.nlargest(10, 'availability_365')
low_available = df_concatenado_Barcelona_copia.nsmallest(10, 'availability_365')

print("Top 10 propiedades con mayor disponibilidad")
print(top_available[['name', 'availability_365']])

print("Top 10 propiedades con menor disponibilidad")
print(low_available[['name', 'availability_365']])

# Boxplot de precios por barrio
plt.figure(figsize=(12, 6))
sns.boxplot(x='neighbourhood_group', y='price', data=df_concatenado_Barcelona_copia)
plt.title('Precios por Barrio')
plt.xlabel('Barrio')
plt.ylabel('Precio')
plt.show()

# Identificar las propiedades con los precios más altos
top_expensive = df_concatenado_Barcelona_copia.nlargest(10, 'price')
print(top_expensive[['name', 'price', 'neighbourhood_group', 'room_type']])

# Propiedades con las mejores calificaciones
top_rated = df_concatenado_Barcelona_copia.nlargest(10, 'number_of_reviews')  # Asumiendo que hay una columna 'review_scores_rating'
print(top_rated[['name', 'number_of_reviews', 'price']])

# Distribución de reseñas
plt.figure(figsize=(10, 6))
sns.histplot(df_concatenado_Barcelona_copia['number_of_reviews'], kde=True, bins=50)
plt.title('Distribución del Número de Reseñas')
plt.xlabel('Número de Reseñas')
plt.ylabel('Frecuencia')
plt.show()

# Propiedades más caras con el mayor número de reseñas
top_expensive_reviews = df_concatenado_Barcelona_copia.nlargest(10, ['price', 'number_of_reviews'])
print(top_expensive_reviews[['name', 'price', 'number_of_reviews']])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38741 entries, 0 to 75144
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38741 non-null  int64
#  1   name                            38741 non-null  object
#  2   host_id                         38741 non-null  int64
#  3   host_name                       38741 non-null  object
#  4   neighbourhood_group             38741 non-null  object
#  5   neighbourhood                   38741 non-null  object
#  6   latitude                        38741 non-null  float64
#  7   longitude                       38741 non-null  float64
#  8   room_type                       38741 non-null  object
#  9   price                           38741 non-null  float64
#  10  minimum_nights                  38741 non-null  int64
#  11  number_of_reviews               38741 non-null  int64
# ...
